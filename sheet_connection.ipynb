# %% [markdown]
# <a href="https://colab.research.google.com/github/rida09Heythere/mental-health-cycle-tracker/blob/main/sheet_connection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gspread oauth2client

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
scope=["https://spreadsheets.google.com/feeds",
       "https://www.googleapis.com/auth/drive"]
creds=ServiceAccountCredentials.from_json_keyfile_name("cycle-tracker-r.json",scope)
client=gspread.authorize(creds)

sheet = client.open("Cycle-Tracker-data").sheet1
print("connected successfully")
# Out:
# connected successfully

# %%
sheet=client.open("Cycle-Tracker-data").sheet1
import datetime
test_row=[
    str(datetime.datetime.now()),
    "Test User",
    "23",
    "Luteal",
    "6",
    "7",
    "Work stress",
    "N/A"

]
sheet.append_row(test_row)
print("Row added successsfully")
# Out:
# Row added successsfully
