# %% [markdown]
# <a href="https://colab.research.google.com/github/rida09Heythere/wellness-anxiety-insight-assistant/blob/main/Recommendation%20Engine%20V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gspread oauth2client

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
scope=["https://spreadsheets.google.com/feeds",
       "https://www.googleapis.com/auth/drive"]
creds=ServiceAccountCredentials.from_json_keyfile_name("cycle-tracker-r.json",scope)
client=gspread.authorize(creds)

sheet = client.open("Anxiety-Tracker-data").worksheet("Health Responses")
print("connected successfully")
# Out:
# connected successfully

# %%
import pandas as pd
print(sheet.get_all_records)
df=pd.DataFrame(sheet.get_all_records())
print(df.columns)
# Out:
# <bound method Worksheet.get_all_records of <Worksheet 'Health Responses' id:2089203399>>
# Index(['Date', 'Gender', 'Name', 'Cycle Phase', 'Sleep Hrs/Day',
#        'Exercise Frequency', 'Anxiety Score (1-10)', 'Anxiety Triggers',
#        'Coping Methods', 'Suggestion Helped', 'Most Anxious Phase',
#        'Symptoms during anxious phase'],
#       dtype='object')

# %%
recommendations = {
            "Responsibilities":[
            "I know you are doing your best more than you are being appreciated",
            "Have faith and keep going along taking care of yourself too",
            "Dont forget yourself during the process",
            "Prioritize tasks by urgency and importance by managemnet",
            "Focus on completing one responsibility at a time"],

            "Low self-esteem":[
            "Dont think your less because of anyone or anything you are the one who will define your worth",
            "Your not less or late just preparing for something big",
            "Before anything first love yourself its the most important thing",
            "Focus on Progress rather than perfection nothing is perfect but your love for yourself will make everything perfect",
            "Write down personal strenghts and good qualities and achievements that you think you have achieved even if its not a big thing YOU MATTER",
            "Avoid comparing yourslef to others , you are not the one that fits in you are the one who STANDS OUT!",
            "You make your own story so dont compare someones finish line with your start line",
            "LOVE YOURSELF "],

            "Studies":[
            "I know your trying as much you can",
            "Relax and study what makes you curious and hook",
            "Set your goals right dont try to study all togethere focus on your filed",
            "Make a strategic Time table ",
            "Make time foe yourself take regular breaks during study sessions and a day off once a week ITS OKAY",
            "Dont mug up before exams just revise what you already learned",
            "Break the topics into smaller parts and learned it from zero to understand the core of topic INTRESTING SESSION",
            "Eat healthy , Be active , get sunlight , take breaks and just study consistently from the start",
            "YOU CAN DO IT"],

            "Health":[
            "I know you are struggling and the frustation that you didnt chose this struggle",
            "DONT GIVE UP Life is a beautiful journey make most of it do everything that benefits you and you have control on foeget things you cant do anything about it",
            "You are special treat yourself that way do what you wish become what you can !",
            "Maintain a healthy lifestyle both physically and mentally",
            "Maintain a good sleep schedule",
            "Move your body , get in touch with mother earth",
            "Dont hesitate to seek help",
            "Seek medical advice and treatment for ongoing health concerns"],

            "Financial":[
            "I know money is tight , this world inflation and increasing needs financial safety is utmost important But guess what afterall its just money YOU CAN DO IT",
 "Do what you like and which makes you curious",
"Learn Money making startegies trends business careers skills and lessons once you master few of them you can literally make money anyhow",
"Make good connections with rich class people trust me it helps alot network plays a big role and it teaches you alot",
"Be consistent on learning and striving you will learn better and make better decision",
"Start Savings its killer for urgent funds",
"Create a Budget plan",
"Track your spendings",
"Spend on valuable stuff which benefits you long term and help you make more money."],

# ...

# %%
print(type(selected_triggers))
# Out:
# <class 'tuple'>

# %%
selected_triggers="Career","Family","Financial"
selected_triggers=[t.strip() for t in selected_triggers]
print(selected_triggers)
# Out:
# ['Career', 'Family', 'Financial']

# %%
for trigger in selected_triggers:
  print("\n"+ trigger + ":")
  for rec in recommendations[trigger]:
    print("-" + rec)
# Out:
# Career:
# -I know its a big thing in your life and you are worried whether it will work or not
# -But remember your hard work today wont go waste at all with right focus and decisions and avoiding distractions
# -just be consistent with your work and skills and keep upgrading yourself in your field until you master it
# -Live and make your life togethere have fun too thats why your earning aferall! dont forget youself in the process
# -Break goals into smaller milestone
# -Focus on skills development , lessons and learn fr
# -Look what jobs are needing the most and work on it
# -Make a good network and learn from them .
#
# Family:
# -I know it hurts when your own people makes you doubt yourself , hurt you , doesnt support you or misunderstand you
# -but always remember your family doesnt define your worth YOU DO
# ...

# %%
selected_triggers=[t.strip() for t in df["Anxiety Triggers"].iloc[0].split(",")]
for trigger in selected_triggers:
  print("\n" + trigger + ":")
  for rec in recommendations[trigger]:
    print("-" + rec)
# Out:
# Financial:
# -I know money is tight , this world inflation and increasing needs financial safety is utmost important But guess what afterall its just money YOU CAN DO IT
# -Do what you like and which makes you curious
# -Learn Money making startegies trends business careers skills and lessons once you master few of them you can literally make money anyhow
# -Make good connections with rich class people trust me it helps alot network plays a big role and it teaches you alot
# -Be consistent on learning and striving you will learn better and make better decision
# -Start Savings its killer for urgent funds
# -Create a Budget plan
# -Track your spendings
# -Spend on valuable stuff which benefits you long term and help you make more money.
#
# Health:
# -I know you are struggling and the frustation that you didnt chose this struggle
# ...

# %%
for index, row in df.iterrows():
  selected_triggers=[t.strip() for t in row["Anxiety Triggers"].split(",")]

  response="Based on your responses,here are some suggestions:\n\n"
  for trigger in selected_triggers:
    if trigger in recommendations:
        response+=f"{trigger}:\n"
        for rec in recommendations[trigger]:
          response+= f" .{rec}\n"
          response+="\n"
    else:
      response+=f"{trigger}:\n"
      response+=((
          "- I understand its tough but you are stronger and you have more things to do and experince head You can  do it\n\n"
          "- Focus on what you can control and be happy\n\n"
          "- Break problems  into smaller steps it will help you\n\n"
          "- Dont hesitate in seeking help to a trusted friend and family or professional.\n\n"))

  print(f"\n----{index+1}:{row['Name']}----\n")
  print(response)
# Out:
# ----1:Rida----
#
# Based on your responses,here are some suggestions:
#
# Financial:
#  .I know money is tight , this world inflation and increasing needs financial safety is utmost important But guess what afterall its just money YOU CAN DO IT
#
#  .Do what you like and which makes you curious
#
#  .Learn Money making startegies trends business careers skills and lessons once you master few of them you can literally make money anyhow
#
#  .Make good connections with rich class people trust me it helps alot network plays a big role and it teaches you alot
#
#  .Be consistent on learning and striving you will learn better and make better decision
#
#  .Start Savings its killer for urgent funds
#
#  .Create a Budget plan
#
#  .Track your spendings
#
#  .Spend on valuable stuff which benefits you long term and help you make more money.
#
# Health:
#  .I know you are struggling and the frustation that you didnt chose this struggle
#
# ...
