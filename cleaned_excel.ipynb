# %% [markdown]
# <a href="https://colab.research.google.com/github/rida09Heythere/wellness-anxiety-insight-assistant/blob/main/cleaned_excel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gspread oauth2client

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
scope=["https://spreadsheets.google.com/feeds",
       "https://www.googleapis.com/auth/drive"]
creds=ServiceAccountCredentials.from_json_keyfile_name("cycle-tracker-r.json",scope)
client=gspread.authorize(creds)

sheet = client.open("Anxiety-Tracker-data").worksheet("Health Responses")
print("connected successfully")
# Out:
# connected successfully

# %%
import pandas as pd
print(sheet.get_all_records)
df=pd.DataFrame(sheet.get_all_records())
print(df.columns)
# Out:
# <bound method Worksheet.get_all_records of <Worksheet 'Health Responses' id:2089203399>>
# Index(['Date', 'Gender', 'Name', 'Cycle Phase', 'Sleep Hrs/Day',
#        'Exercise Frequency', 'Anxiety Score (1-10)', 'Anxiety Triggers',
#        'Coping Methods', 'Suggestion Helped', 'Most Anxious Phase',
#        'Symptoms during anxious phase'],
#       dtype='object')

# %%
from collections import Counter
all_triggers=[]
for triggers in df["Anxiety Triggers"]:
    all_triggers.extend([t.strip() for t in triggers.split(",") if t.strip()]) # Filter out empty strings
triggers_counts=Counter(all_triggers)
trigger_counts=pd.Series(Counter(all_triggers)).sort_values(ascending=False)
print(trigger_counts)

trigger_df=pd.DataFrame({"Triggers":all_triggers})
trigger_df.head()
# Out:
# Relationship        12
# Career              10
# Financial            9
# Family               8
# Future               7
# Health               6
# Low self-esteem      4
# Studies              4
# Social               2
# Responsibilities     1
# Failing              1
# none                 1
# Low self esteem      1
# My whole life        1
# dtype: int64
#           Triggers
# 0        Financial
# 1           Health
# 2     Relationship
# 3  Low self-esteem
# 4           Future

# %%
trigger_df.to_excel("cleaned_triggers.xlsx",index="False")
trigger_df.head(20)
# Out:
#             Triggers
# 0          Financial
# 1             Health
# 2       Relationship
# 3    Low self-esteem
# 4             Future
# 5             Family
# 6            Studies
# 7             Career
# 8             Family
# 9             Future
# 10      Relationship
# 11  Responsibilities
# 12      Relationship
# 13            Career
# 14            Health
# 15           Failing
# 16            Career
# 17         Financial
# 18         Financial
# 19         Financial

# %%
cleaned_triggers.xlsx

# %%
from collections import Counter
all_coping=[]
for coping in df["Coping Methods"]:
  all_coping.extend(c.strip() for c in coping.split(",") if c.strip())
coping_counts=Counter(all_coping)
coping_counts=pd.Series(Counter(all_coping)).sort_values(ascending=False)
print(coping_counts)
coping_df=pd.DataFrame({"Coping Methods":all_coping})
coping_df.to_excel("cleaned_coping.xlsx",index=False)
coping_df.head()
# Out:
# Sleeping                    11
# Eating                      10
# Music                        6
# Exercise                     5
# Droomscroll/netflix          4
# Prayer                       3
# Travelling                   3
# Talking to friend/family     2
# Self harm                    2
# none                         1
# Gaming                       1
# Prayers                      1
# dtype: int64
#         Coping Methods
# 0               Prayer
# 1                Music
# 2               Eating
# 3             Sleeping
# 4  Droomscroll/netflix

# %%
all_emotions=[]
for emotion in df["Symptoms during anxious phase"]:
  all_emotions.extend(e.strip() for e in str(emotion).split(",")if e.strip())
emotion_df=pd.DataFrame({"Emotion":all_emotions})
emotion_df.to_excel("cleaned_emotions.xlsx",index=False)
emotion_df.head()
# Out:
#       Emotion
# 0      Stress
# 1    Bad mood
# 2      Freaky
# 3      Cranky
# 4  Sad scared
